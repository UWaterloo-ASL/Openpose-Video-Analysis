# %% [markdown]
# # ROM Video Analyzing
# * To run this note, you need to install Openpose following [Steps to Install Openpose in ComputeCanada Cluster](https://docs.google.com/document/d/1vQCQD2iet-K1ZAjTns2aEp-q7R-w8fCQ55jVzriWLV0/edit?usp=sharing)
# * To set up Jupyter Notebook and submit jobs in Compute Canada Clusters, please refer to [Steps to Use Openpose Analyzing Video](https://docs.google.com/document/d/1tozpc-KpAHVjQOx5XkW0pDYbd8IKKCD45Omk-RvFNcg/edit?usp=sharing)

# %%
import os
os.system('module load nixpkgs/16.09  gcc/5.4.0  cuda/8.0.44  cudnn/7.0 opencv/3.3.0  boost/1.65.1 openblas/0.2.20 hdf5/1.8.18 leveldb/1.18 mkl-dnn/0.14 python/3.5.2')
os.system('cd ~')
os.system('source openposeEnv_Python3/bin/activate')
os.system('export LD_LIBRARY_PATH=$LD_LIBRARY_PATH:$HOME/openpose_python_lib/lib:$HOME/openpose_python_lib/python/openpose:$HOME/caffe/build/lib:/cvmfs/soft.computecanada.ca/easybuild/software/2017/avx2/Compiler/gcc5.4/boost/1.65.1/lib')
# Out:
# 0

# %%
# From Python
# It requires OpenCV installed for Python
import sys
import cv2
import os
from sys import platform
import argparse

import pdb
from IPython.core.debugger import Tracer

# Remember to add your installation path here
# Option b
# If you run `make install` (default path is `/usr/local/python` for Ubuntu), you can also access the OpenPose/python module from there. This will install OpenPose and the python library at your desired installation path. Ensure that this is in your python path in order to use it.
sys.path.insert(0,r'/home/lingheng/openpose_python_lib/python/openpose') 

# Parameters for OpenPose. Take a look at C++ OpenPose example for meaning of components. Ensure all below are filled
try:
    from openpose import *
except:
    raise Exception('Error: OpenPose library could not be found. Did you enable `BUILD_PYTHON` in CMake and have this Python script in the right folder?')
params = dict()
params["logging_level"] = 3
params["output_resolution"] = "-1x-1"
params["net_resolution"] = "-1x368" # if crop video, this should be changged and must be mutplies of 16.
params["model_pose"] = "BODY_25"
params["alpha_pose"] = 0.6
params["scale_gap"] = 0.3
params["scale_number"] = 1
params["render_threshold"] = 0.05
# If GPU version is built, and multiple GPUs are available, set the ID here
params["num_gpu_start"] = 0
params["disable_blending"] = False
# Ensure you point to the correct path where models are located
params["default_model_folder"] = "/home/lingheng/openpose/models/"
# Construct OpenPose object allocates GPU memory
openpose = OpenPose(params)

# %%
# construct the argument parser and parse the arguments
args = dict()
args['video']='/home/lingheng/project/lingheng/ROM_Video_Process/ROM_raw_videos/Sep_12_2pm_3pm.mp4'
args['output_directory']='/home/lingheng/project/lingheng/ROM_Video_Process/ROM_processed_videos_2'

if args.get("video", None) is None:
    raise Error("No input video!!")
# otherwise, we are reading from a video file
else:
    camera = cv2.VideoCapture(args["video"])
# frames per second (fps) in the raw video
fps = camera.get(cv2.CAP_PROP_FPS)
frame_count = 1
print("Raw frames per second: {0}".format(fps))
# prepare to save video
(grabbed, frame) = camera.read()
# downsample frame
downsample_rate = 0.5
frame = cv2.resize(frame,None,fx=downsample_rate, fy=downsample_rate, interpolation = cv2.INTER_LINEAR)
# crop frame
original_h, original_w, channels= frame.shape
top_edge = int(original_h*(1/10))
down_edge = int(original_h*1)
left_edge = int(original_w*(1/5))
right_edge = int(original_w*(4/5))
frame_cropped = frame[top_edge:down_edge,left_edge:right_edge,:].copy() # must use copy(), otherwise slice only return address i.e. not hard copy

fheight, fwidth, channels = frame_cropped.shape
#pdb.set_trace()
print("Frame width:{}, Frame height:{}.".format(fwidth , fheight))

# get output file name
file_path = args["video"].split('/')
file_name, _= file_path[-1].split('.')
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out_camera_frame = cv2.VideoWriter(os.path.join(args['output_directory'],'{}_processed.avi'.format(file_name)),fourcc, fps, (fwidth,fheight))
# Out:
# Raw frames per second: 23.209837217316796
# Frame width:576, Frame height:486.

# %%
camera.get(cv2.CAP_PROP_FRAME_COUNT)
# Out:
# 83647.0

# %%
# loop over the frames of the video
total_frame_number = camera.get(cv2.CAP_PROP_FRAME_COUNT)
for frame_count in range(int(total_frame_number)):
    if frame_count % 200 == 0:
        print('Processing frame: {}'.format(frame_count))
    (grabbed, frame) = camera.read()
    if grabbed == True:
        time = camera.get(cv2.CAP_PROP_POS_MSEC) #Current position of the video file in milliseconds.
        # downsample frame
        frame = cv2.resize(frame,None,fx=downsample_rate, fy=downsample_rate, interpolation = cv2.INTER_LINEAR)
        # crop frame
        frame_cropped = frame[top_edge:down_edge,left_edge:right_edge,:].copy() # must use copy()
        #pdb.set_trace()
        # Output keypoints and the image with the human skeleton blended on it
        keypoints, output_image = openpose.forward(frame_cropped, True)
        # Print the human pose keypoints, i.e., a [#people x #keypoints x 3]-dimensional numpy object with the keypoints of all the people on that image
        #print(keypoints.shape)

        # draw the text and timestamp on the frame
        occupancy = keypoints.shape[0]
        cv2.putText(output_image, "Current Occupancy: {}".format(occupancy), (10, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
        with open(os.path.join(args['output_directory'],'{}_processed_occupancy.txt'.format(file_name)), "a+") as fh:
           fh.write("{},{}\r".format(time, occupancy))
        #Tracer()()
        # save video
        #cv2.imwrite('messigray_1gpu_cropped2.png',output_image)
        #cv2.imwrite('messigray_1gpu_cropped2_frame.png',frame_cropped)
        out_camera_frame.write(output_image)
    else:
        # Pass this frame if cannot grab an image.
        print('Frame: {}, grabbed={} and frame={}'.format(frame_count, grabbed, frame))
    # waite for a pressed key
    #cv2.waitKey(1)
# Out:
# Processing frame: 0
# Processing frame: 200
# Processing frame: 400
# Processing frame: 600
# Processing frame: 800
# Processing frame: 1000
# Processing frame: 1200
# Processing frame: 1400
# Processing frame: 1600
# Processing frame: 1800
# Processing frame: 2000
# Processing frame: 2200
# Processing frame: 2400
# Processing frame: 2600
# Processing frame: 2800
# Processing frame: 3000
# Processing frame: 3200
# Processing frame: 3400
# Processing frame: 3600
# Processing frame: 3800
# Processing frame: 4000
# Processing frame: 4200
# Processing frame: 4400
# Processing frame: 4600
# Processing frame: 4800
# Processing frame: 5000
# Processing frame: 5200
# Processing frame: 5400
# Processing frame: 5600
# Processing frame: 5800
# Processing frame: 6000
# Processing frame: 6200
# Processing frame: 6400
# Processing frame: 6600
# Processing frame: 6800
# Processing frame: 7000
# Processing frame: 7200
# Processing frame: 7400
# Processing frame: 7600
# Processing frame: 7800
# Processing frame: 8000
# Processing frame: 8200
# Processing frame: 8400
# Processing frame: 8600
# Processing frame: 8800
# Processing frame: 9000
# Processing frame: 9200
# Processing frame: 9400
# Processing frame: 9600
# Processing frame: 9800
# Processing frame: 10000
# Processing frame: 10200
# Processing frame: 10400
# Processing frame: 10600
# Processing frame: 10800
# Processing frame: 11000
# Processing frame: 11200
# Processing frame: 11400
# Processing frame: 11600
# Processing frame: 11800
# Processing frame: 12000
# Processing frame: 12200
# Processing frame: 12400
# Processing frame: 12600
# Processing frame: 12800
# Processing frame: 13000
# Processing frame: 13200
# Processing frame: 13400
# Processing frame: 13600
# Processing frame: 13800
# Processing frame: 14000
# Processing frame: 14200
# Processing frame: 14400
# Processing frame: 14600
# Processing frame: 14800
# Processing frame: 15000
# Processing frame: 15200
# Processing frame: 15400
# Processing frame: 15600
# Processing frame: 15800
# Processing frame: 16000
# Processing frame: 16200
# Processing frame: 16400
# Processing frame: 16600
# Processing frame: 16800
# Processing frame: 17000
# Processing frame: 17200
# Processing frame: 17400
# Processing frame: 17600
# Processing frame: 17800
# Processing frame: 18000
# Processing frame: 18200
# Processing frame: 18400
# Processing frame: 18600
# Processing frame: 19600
# Processing frame: 19800
# Processing frame: 20000
# Processing frame: 20200
# Processing frame: 20400
# Processing frame: 20600
# Processing frame: 20800
# Processing frame: 21000
# Processing frame: 21200
# Processing frame: 21400
# Processing frame: 21600
# Processing frame: 21800
# Processing frame: 22000
# Processing frame: 22200
# Processing frame: 22400
# Frame: 22540, grabbed=False and frame=None
# Frame: 22541, grabbed=False and frame=None
# Frame: 22542, grabbed=False and frame=None
# Frame: 22543, grabbed=False and frame=None
# Frame: 22544, grabbed=False and frame=None
# Frame: 22545, grabbed=False and frame=None
# Frame: 22546, grabbed=False and frame=None
# Frame: 22547, grabbed=False and frame=None
# Frame: 22548, grabbed=False and frame=None
# Frame: 22549, grabbed=False and frame=None
# Frame: 22550, grabbed=False and frame=None
# Frame: 22551, grabbed=False and frame=None
# Frame: 22552, grabbed=False and frame=None
# Frame: 22553, grabbed=False and frame=None
# Frame: 22554, grabbed=False and frame=None
# Frame: 22555, grabbed=False and frame=None
# Frame: 22556, grabbed=False and frame=None
# Frame: 22557, grabbed=False and frame=None
# Frame: 22558, grabbed=False and frame=None
# Frame: 22560, grabbed=False and frame=None
# Frame: 22561, grabbed=False and frame=None
# Frame: 22563, grabbed=False and frame=None
# Frame: 22564, grabbed=False and frame=None
# Frame: 22566, grabbed=False and frame=None
# Frame: 22567, grabbed=False and frame=None
# Frame: 22569, grabbed=False and frame=None
# Frame: 22570, grabbed=False and frame=None
# Processing frame: 22600
# Processing frame: 22800
# Processing frame: 23000
# Processing frame: 23200
# Processing frame: 23400
# Processing frame: 23600
# Processing frame: 23800
# Processing frame: 24000
# Processing frame: 24200
# Processing frame: 24400
# Processing frame: 24600
# Processing frame: 24800
# Processing frame: 25000
# Processing frame: 25200
# Processing frame: 25400
# Processing frame: 25600
# Processing frame: 25800
# Processing frame: 26000
# Processing frame: 26200
# Processing frame: 26400
# Processing frame: 26600
# Processing frame: 26800
# Processing frame: 27000
# Processing frame: 27200
# Processing frame: 27400
# Processing frame: 27600
# Processing frame: 27800
# Processing frame: 28000
# Processing frame: 28200
# Processing frame: 28400
# Processing frame: 28600
# Processing frame: 28800
# Processing frame: 29000
# Processing frame: 29200
# Processing frame: 29400
# Processing frame: 29600
# Processing frame: 29800
# Processing frame: 30000
# Processing frame: 30200
# Processing frame: 30400
# Processing frame: 30600
# Processing frame: 30800
# Processing frame: 31000
# Processing frame: 31200
